# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (from opencv-python) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\users\admin\anaconda3\envs\notebook\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


video_path = "C:\\Users\\ADMIN\\Downloads\\Tom and jerry little quacker status video.mp4"
template_path = "C:\\Users\\ADMIN\\Downloads\\PYTHON 5th SEM\\jeery.png"


video = cv2.VideoCapture(video_path)
template = cv2.imread(template_path, cv2.IMREAD_GRAYSCALE)


if not video.isOpened():
    print("Error: Could not open video.")
    exit()

if template is None:
    print("Error: Could not load template image.")
    exit()

w, h = template.shape[::-1]


threshold = 0.6  


while True:
    ret, frame = video.read()
    
    if not ret:
        break
    
   
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
  
    if template.shape[0] > gray_frame.shape[0] or template.shape[1] > gray_frame.shape[1]:
        template = cv2.resize(template, (min(template.shape[1], gray_frame.shape[1]), min(template.shape[0], gray_frame.shape[0])))
        w, h = template.shape[::-1]  
    
   
    result = cv2.matchTemplate(gray_frame, template, cv2.TM_CCOEFF_NORMED)
    
    
    locations = np.where(result >= threshold)
    
 
    if len(locations[0]) == 0:
        print("No matches found in this frame.")
    else:
        print("Match found!")
    
 
    for pt in zip(*locations[::-1]):
        cv2.rectangle(frame, pt, (pt[0] + w, pt[1] + h), (0, 255, 255), 3)
    
    
    cv2.imshow("Template Matching", frame)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break


video.release()
cv2.destroyAllWindows()
# Out:
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.
# No matches found in this frame.

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

# %%
template=cv2.imread("C:\\Users\\ADMIN\\Downloads\\PYTHON 5th SEM\\jeery.png")
plt.imshow(template)
plt.axis('off')  # Optional: hides axes
plt.title("iput_image")
plt.show()
template =cv2.imread("C:\\Users\\ADMIN\\Downloads\\PYTHON 5th SEM\\jeery.png")
plt.imshow(template)
plt.axis('off')  # Optional: hides axes
plt.title("output")
plt.show()
